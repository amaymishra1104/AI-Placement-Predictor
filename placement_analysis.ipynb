# %%
import pandas as pd

# %%
import os

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '.venv', 'data.csv', 'placement_analysis.ipynb']

# %%
# Load training and test data
train_df = pd.read_csv("data.csv/train.csv")
test_df = pd.read_csv("data.csv/test.csv")

print(f"Training data shape: {train_df.shape}")
print(f"Test data shape: {test_df.shape}")
# Out:
# Training data shape: (45000, 15)
# Test data shape: (5000, 15)

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv/train.csv")

# %%
df.head()
# Out:
#    Student_ID  Age  Gender  Degree Branch  CGPA  Internships  Projects  \
# 0        1048   22  Female  B.Tech    ECE  6.29            0         3
# 1       37820   20  Female     BCA    ECE  6.05            1         4
# 2       49668   22    Male     MCA     ME  7.22            1         4
# 3       19467   22    Male     MCA     ME  7.78            2         4
# 4       23094   20  Female  B.Tech     ME  7.63            1         4
#
#    Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# 0              4                     6                   51
# 1              6                     8                   59
# 2              6                     6                   58
# 3              6                     6                   90
# 4              6                     5                   79
#
#    Soft_Skills_Rating  Certifications  Backlogs Placement_Status
# 0                   5               1         3       Not Placed
# ...

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Degree', 'Branch', 'CGPA',
#        'Internships', 'Projects', 'Coding_Skills', 'Communication_Skills',
#        'Aptitude_Test_Score', 'Soft_Skills_Rating', 'Certifications',
#        'Backlogs', 'Placement_Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (45000, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Student_ID            45000 non-null  int64
#  1   Age                   45000 non-null  int64
#  2   Gender                45000 non-null  object
#  3   Degree                45000 non-null  object
#  4   Branch                45000 non-null  object
#  5   CGPA                  45000 non-null  float64
#  6   Internships           45000 non-null  int64
#  7   Projects              45000 non-null  int64
#  8   Coding_Skills         45000 non-null  int64
#  9   Communication_Skills  45000 non-null  int64
#  10  Aptitude_Test_Score   45000 non-null  int64
#  11  Soft_Skills_Rating    45000 non-null  int64
#  12  Certifications        45000 non-null  int64
#  13  Backlogs              45000 non-null  int64
#  14  Placement_Status      45000 non-null  object
# ...

# %%
df.describe()
# Out:
#          Student_ID           Age          CGPA   Internships      Projects  \
# count  45000.000000  45000.000000  45000.000000  45000.000000  45000.000000
# mean   24977.962600     20.999333      7.002290      0.774089      3.734222
# std    14425.605704      1.995071      0.993855      0.844750      0.923738
# min        1.000000     18.000000      4.500000      0.000000      1.000000
# 25%    12509.750000     19.000000      6.320000      0.000000      3.000000
# 50%    24957.500000     21.000000      7.000000      1.000000      4.000000
# 75%    37475.250000     23.000000      7.670000      1.000000      4.000000
# max    50000.000000     24.000000      9.800000      3.000000      6.000000
#
#        Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# count   45000.000000          45000.000000         45000.000000
# mean        5.691800              5.501644            69.385356
# std         1.994674              1.515374            13.909710
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID              0
# Age                     0
# Gender                  0
# Degree                  0
# Branch                  0
# CGPA                    0
# Internships             0
# Projects                0
# Coding_Skills           0
# Communication_Skills    0
# Aptitude_Test_Score     0
# Soft_Skills_Rating      0
# Certifications          0
# Backlogs                0
# Placement_Status        0
# dtype: int64

# %%
df['Placement_Status'].value_counts()
# Out:
# Placement_Status
# Not Placed    28688
# Placed        16312
# Name: count, dtype: int64

# %%
df.groupby('Placement_Status').mean(numeric_only=True)
# Out:
#                     Student_ID        Age      CGPA  Internships  Projects  \
# Placement_Status
# Not Placed        24897.167666  20.994736  6.633941     0.579406  3.385388
# Placed            25120.057075  21.007418  7.650109     1.116479  4.347719
#
#                   Coding_Skills  Communication_Skills  Aptitude_Test_Score  \
# Placement_Status
# Not Placed             5.030919              5.129322            65.293712
# Placed                 6.854095              6.156449            76.581351
#
#                   Soft_Skills_Rating  Certifications  Backlogs
# Placement_Status
# Not Placed                  5.504845        1.568182  1.247978
# Placed                      5.496015        2.210336  0.255272

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Degree', 'Branch', 'CGPA',
#        'Internships', 'Projects', 'Coding_Skills', 'Communication_Skills',
#        'Aptitude_Test_Score', 'Soft_Skills_Rating', 'Certifications',
#        'Backlogs', 'Placement_Status'],
#       dtype='object')

# %%
df.columns[0]
# Out:
# 'Student_ID'

# %%
df.columns[df.columns.str.contains('Placement_Status')]
# Out:
# Index(['Placement_Status'], dtype='object')

# %%
print("Target column is Placement_Status")
# Out:
# Target column is Placement_Status

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    Student_ID  Age  CGPA  Internships  Projects  Coding_Skills  \
# 0        1048   22  6.29            0         3              4
# 1       37820   20  6.05            1         4              6
# 2       49668   22  7.22            1         4              6
# 3       19467   22  7.78            2         4              6
# 4       23094   20  7.63            1         4              6
#
#    Communication_Skills  Aptitude_Test_Score  Soft_Skills_Rating  \
# 0                     6                   51                   5
# 1                     8                   59                   8
# 2                     6                   58                   6
# 3                     6                   90                   4
# 4                     5                   79                   6
#
#    Certifications  Backlogs  Gender_Male  Degree_B.Tech  Degree_BCA  \
# 0               1         3        False           True       False
# ...

# %%
df.shape
# Out:
# (45000, 20)

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'CGPA', 'Internships', 'Projects', 'Coding_Skills',
#        'Communication_Skills', 'Aptitude_Test_Score', 'Soft_Skills_Rating',
#        'Certifications', 'Backlogs', 'Gender_Male', 'Degree_B.Tech',
#        'Degree_BCA', 'Degree_MCA', 'Branch_Civil', 'Branch_ECE', 'Branch_IT',
#        'Branch_ME', 'Placement_Status_Placed'],
#       dtype='object')

# %%
df.groupby('Placement_Status_Placed')['CGPA'].mean().plot(kind='bar')
plt.title("CGPA vs Placement")
plt.show()

# %%
df.groupby('Placement_Status_Placed')['Internships'].mean()
# Out:
# Placement_Status_Placed
# False    0.579406
# True     1.116479
# Name: Internships, dtype: float64

# %%
df.groupby('Placement_Status_Placed')['Projects'].mean()
# Out:
# Placement_Status_Placed
# False    3.385388
# True     4.347719
# Name: Projects, dtype: float64

# %%
df.groupby('Placement_Status_Placed')['Internships'].mean().plot(kind='bar')
plt.title("Internships vs Placement")
plt.show()

# %% [markdown]
# **Observation of above data :**
#
# Higher CGPA students placed more
#
# Internships affect placement
#
# Projects matter
